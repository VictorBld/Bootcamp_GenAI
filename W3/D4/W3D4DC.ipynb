# %%
import pandas as pd

df = pd.read_csv("train.csv")
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %% [markdown]
# DATA CLEANING AND PREPROCESSING
#
# No missing data & only float/integer so we don't need to do anything

# %%
# Calculate central tendency measures for each numerical feature
for col in df.select_dtypes(include=['number']):
    print(f"Feature: {col}")
    print(f"  Mean: {df[col].mean()}")
    print(f"  Median: {df[col].median()}")
    print(f"  Mode: {df[col].mode()[0]}\n") # Access the first mode value

# Dispersion measures (range, variance, standard deviation, IQR)
for col in df.select_dtypes(include=['number']):
    print(f"Feature: {col}")
    print(f"  Range: {df[col].max() - df[col].min()}")
    print(f"  Variance: {df[col].var()}")
    print(f"  Standard Deviation: {df[col].std()}")
    print(f"  IQR: {df[col].quantile(0.75) - df[col].quantile(0.25)}\n")


# Shape (Skewness and Kurtosis)
for col in df.select_dtypes(include=['number']):
    print(f"Feature: {col}")
    print(f"  Skewness: {df[col].skew()}")
    print(f"  Kurtosis: {df[col].kurt()}\n")
# Out:
# Feature: battery_power
#   Mean: 1238.5185
#   Median: 1226.0
#   Mode: 618
#
# Feature: blue
#   Mean: 0.495
#   Median: 0.0
#   Mode: 0
#
# Feature: clock_speed
#   Mean: 1.52225
#   Median: 1.5
#   Mode: 0.5
#
# Feature: dual_sim
#   Mean: 0.5095
#   Median: 1.0
#   Mode: 1
#
# Feature: fc
#   Mean: 4.3095
#   Median: 3.0
#   Mode: 0
#
# Feature: four_g
#   Mean: 0.5215
#   Median: 1.0
#   Mode: 1
#
# Feature: int_memory
#   Mean: 32.0465
#   Median: 32.0
#   Mode: 27
#
# Feature: m_dep
#   Mean: 0.50175
#   Median: 0.5
#   Mode: 0.1
#
# Feature: mobile_wt
#   Mean: 140.249
#   Median: 141.0
#   Mode: 182
#
# Feature: n_cores
#   Mean: 4.5205
#   Median: 4.0
#   Mode: 4
#
# Feature: pc
#   Mean: 9.9165
#   Median: 10.0
#   Mode: 10
#
# Feature: px_height
#   Mean: 645.108
#   Median: 564.0
#   Mode: 347
#
# Feature: px_width
#   Mean: 1251.5155
#   Median: 1247.0
#   Mode: 874
#
# Feature: ram
#   Mean: 2124.213
#   Median: 2146.5
#   Mode: 1229
#
# Feature: sc_h
# ...

# %%
corr= df.corr()
corr
# sns.heatmap(corr, annot=True,linewidths=0.9)
# plt.show()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
import pandas as pd
from scipy.stats import pearsonr, spearmanr


# Calculate Pearson correlation between numerical features and target variable ('price_range')
for col in df.select_dtypes(include=['number']):
  if col != 'price_range':  # Exclude the target variable itself
    correlation, p_value = pearsonr(df[col], df['price_range'])
    print(f"Pearson Correlation between {col} and price_range: {correlation:.3f}, P-value: {p_value:.3f}")

print("\n")

# Calculate Spearman rank correlation
for col in df.select_dtypes(include=['number']):
  if col != 'SalePrice':
    correlation, p_value = spearmanr(df[col], df['price_range'])
    print(f"Spearman Rank Correlation between {col} and price_range: {correlation:.3f}, P-value: {p_value:.3f}")
# Out:
# Pearson Correlation between battery_power and price_range: 0.201, P-value: 0.000
# Pearson Correlation between blue and price_range: 0.021, P-value: 0.358
# Pearson Correlation between clock_speed and price_range: -0.007, P-value: 0.768
# Pearson Correlation between dual_sim and price_range: 0.017, P-value: 0.436
# Pearson Correlation between fc and price_range: 0.022, P-value: 0.325
# Pearson Correlation between four_g and price_range: 0.015, P-value: 0.509
# Pearson Correlation between int_memory and price_range: 0.044, P-value: 0.047
# Pearson Correlation between m_dep and price_range: 0.001, P-value: 0.970
# Pearson Correlation between mobile_wt and price_range: -0.030, P-value: 0.176
# Pearson Correlation between n_cores and price_range: 0.004, P-value: 0.844
# Pearson Correlation between pc and price_range: 0.034, P-value: 0.133
# Pearson Correlation between px_height and price_range: 0.149, P-value: 0.000
# ...

# %%
from scipy.stats import kendalltau

for col in df.select_dtypes(include=['number']):
  if col != 'price_range':
    correlation, p_value = kendalltau(df[col], df['price_range'])
    print(f"Kendall's Tau Correlation between {col} and price_range: {correlation:.3f}, P-value: {p_value:.3f}")
# Out:
# Kendall's Tau Correlation between battery_power and price_range: 0.148, P-value: 0.000
# Kendall's Tau Correlation between blue and price_range: 0.019, P-value: 0.358
# Kendall's Tau Correlation between clock_speed and price_range: -0.004, P-value: 0.823
# Kendall's Tau Correlation between dual_sim and price_range: 0.016, P-value: 0.435
# Kendall's Tau Correlation between fc and price_range: 0.019, P-value: 0.288
# Kendall's Tau Correlation between four_g and price_range: 0.013, P-value: 0.509
# Kendall's Tau Correlation between int_memory and price_range: 0.033, P-value: 0.048
# Kendall's Tau Correlation between m_dep and price_range: -0.000, P-value: 0.989
# Kendall's Tau Correlation between mobile_wt and price_range: -0.023, P-value: 0.174
# Kendall's Tau Correlation between n_cores and price_range: 0.004, P-value: 0.832
# Kendall's Tau Correlation between pc and price_range: 0.025, P-value: 0.142
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



plt.figure(figsize=(8, 6))
sns.histplot(df['price_range'], kde=True)
plt.title(f'Distribution of price_range')
plt.xlabel('price_range')
plt.ylabel('Frequency')
plt.show()

# Scatter plots (example: 'price_range' vs. 'battery_power')
plt.figure(figsize=(8, 6))
sns.scatterplot(x='battery_power', y='price_range', data=df)
plt.title('Relationship between price_range and battery_power')
plt.xlabel('barrery_power')
plt.ylabel('price_range')
plt.show()

# Box plots (example: 'price_range' across different 'n_cores' categories)
plt.figure(figsize=(10, 6))
sns.boxplot(x='n_cores', y='price_range', data=df)
plt.title('price_range Distribution by n_cores')
plt.xlabel('n_cores')
plt.ylabel('price_range')
plt.xticks(rotation=45) # Rotate x-axis labels if needed
plt.show()

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.9)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# Given the results of our correlation matrix, we can see that "Ram" has a significant impact on our price range. Battery power also has an impact, but for the other features, it is difficult to determine how much they influence the price range.
